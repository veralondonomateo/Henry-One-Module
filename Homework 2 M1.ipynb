# %% [markdown]
# # Práctica Clase 2

# %% [markdown]
# 1) Abrir el archivo "Emisiones_CO2.csv" y cargar sus datos en un diccionario.

# %%
import os
archivo = open('Emisiones_CO2.csv', 'r', encoding='latin-1')

# %%
dicc_emisiones = {  'cod_pais' : [],
                    'nom_pais' : [],
                    'region' : [],
                    'anio' : [],
                    'co2' : [],
                    'co2_percapita' : []}

# %%
x = 0
for i in archivo:
    if x > 0:
        campo = i.split(sep = '|')
        dicc_emisiones["cod_pais"].append(campo[0])
        dicc_emisiones['nom_pais'].append(campo[1])
        dicc_emisiones["region"].append(campo[2])
        dicc_emisiones["anio"].append(campo[3])
        dicc_emisiones["co2"].append(campo[4])
        dicc_emisiones["co2_percapita"].append(campo[5])
    else:
        x += 1

# %%
archivo.close()

# %%
print(dicc_emisiones)
# Out:
# {'cod_pais': ['ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'AGO', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ALB', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARE', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARG', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ARM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ASM', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'ATG', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'AU ...

# %% [markdown]
# 2) a) ¿Cuántas variables hay? <br>
# b) ¿Qué tipos de datos usar para cada una? <br>
# c) ¿Qué tipo de variables son? <br>
# d) ¿Hay valores faltantes? <br>
# e) ¿Cuál es el total de emisiones de CO2 para 'América Latina y Caribe' en el año 2010?

# %%
dicc_emisiones["region"][3]
# Out:
# 'América Latina y Caribe'

# %%
filtro = "América Latina y Caribe"
año = "2010"
emisiones_co2 = 0
indices = []
for indice,lugar in enumerate(dicc_emisiones["region"]):
    if lugar == filtro:
        if dicc_emisiones["anio"][indice] == año:
            indices.append(indice)


for i in indices:
    if dicc_emisiones["co2"][i] != "":

        numero = dicc_emisiones["co2"][i]
        numero = numero.replace(",","")
        numero = numero[:4]
        emisiones_co2 += float(numero)
print(round(emisiones_co2,3))
# Out:
# 32960.58
